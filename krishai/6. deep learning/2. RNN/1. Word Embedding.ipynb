# %% [markdown]
# ## Word Embedding Techniques using Embedding Layer in Keras

# %%
### Libraries used Tensorflow > 2.0 and Keras
import numpy as np

import tensorflow as tf
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential

print(tf.__version__)
# Out:
# 2.9.1

# %%
### sentences
sent=[  'the glass of milk',
     'the glass of juice',
     'the cup of tea',
    'I am a good boy',
     'I am a good developer',
     'understand the meaning of words',
     'your videos are good']

sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup of tea',
#  'I am a good boy',
#  'I am a good developer',
#  'understand the meaning of words',
#  'your videos are good']

# %%
## Vocabulary size
voc_size = 500

# %% [markdown]
# ### One Hot Representation

# %%
one_hot_repr = [one_hot(words, voc_size) for words in sent]
print(one_hot_repr)
# Out:
# [[15, 190, 99, 19], [15, 190, 99, 102], [15, 233, 99, 129], [194, 282, 252, 13, 11], [194, 282, 252, 13, 282], [422, 15, 25, 99, 421], [119, 258, 117, 13]]

# %% [markdown]
# ### Word Embedding Representation

# %%
## pre pading
sent_length = 8
embedded_docs = pad_sequences(one_hot_repr, padding="pre", maxlen=sent_length)
print(embedded_docs)
# Out:
# [[  0   0   0   0  15 190  99  19]
#  [  0   0   0   0  15 190  99 102]
#  [  0   0   0   0  15 233  99 129]
#  [  0   0   0 194 282 252  13  11]
#  [  0   0   0 194 282 252  13 282]
#  [  0   0   0 422  15  25  99 421]
#  [  0   0   0   0 119 258 117  13]]

# %%
## 10 feature dimensions
dim = 10

# %%
model = Sequential()
model.add(Embedding(voc_size, dim, input_length=sent_length))
model.compile('adam', 'mse')

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             5000
#
# =================================================================
# Total params: 5,000
# Trainable params: 5,000
# Non-trainable params: 0
# _________________________________________________________________

# %%
## "the glass of milk"
embedded_docs[0]
# Out:
# array([  0,   0,   0,   0,  15, 190,  99,  19])

# %%
model.predict(embedded_docs[0])
# Out:
# WARNING:tensorflow:Model was constructed with shape (None, 8) for input KerasTensor(type_spec=TensorSpec(shape=(None, 8), dtype=tf.float32, name='embedding_input'), name='embedding_input', description="created by layer 'embedding_input'"), but it was called on an input with incompatible shape (None,).
# 1/1 [==============================] - 0s 136ms/step
# array([[-0.03611733,  0.02915761,  0.00326975, -0.04671866, -0.01129211,
#         -0.02177311, -0.03593468,  0.04195067, -0.01710625, -0.04313778],
#        [-0.03611733,  0.02915761,  0.00326975, -0.04671866, -0.01129211,
#         -0.02177311, -0.03593468,  0.04195067, -0.01710625, -0.04313778],
#        [-0.03611733,  0.02915761,  0.00326975, -0.04671866, -0.01129211,
#         -0.02177311, -0.03593468,  0.04195067, -0.01710625, -0.04313778],
#        [-0.03611733,  0.02915761,  0.00326975, -0.04671866, -0.01129211,
#         -0.02177311, -0.03593468,  0.04195067, -0.01710625, -0.04313778],
#        [-0.02994334, -0.01358159,  0.04053667,  0.01019569,  0.03716693,
#          0.04119015,  0.049212  ,  0.04843136, -0.01219583,  0.02202605],
#        [-0.0241388 , -0.00855054,  0.04701408, -0.02643153,  0.04053856,
#         -0.04300989, -0.02631006, -0.01005584, -0.04359517,  0.00297047],
#        [-0.01246744, -0.02971818, -0.01459314,  0.02737241,  0.03136139,
#          0.02921854,  0.03686709,  0.00905712,  0.00560155, -0.02899699],
#        [-0.04633006,  0.00451602,  0.00017029, -0.03736377, -0.01642824,
#         -0.01172442,  0.02782973,  0.02503386,  0.04141965,  0.01033479]],
#       dtype=float32)

# %%
embedded_docs.shape
# Out:
# (7, 8)

# %%
model.predict(embedded_docs)
# Out:
# 1/1 [==============================] - 0s 25ms/step
# array([[[-0.03611733,  0.02915761,  0.00326975, -0.04671866,
#          -0.01129211, -0.02177311, -0.03593468,  0.04195067,
#          -0.01710625, -0.04313778],
#         [-0.03611733,  0.02915761,  0.00326975, -0.04671866,
#          -0.01129211, -0.02177311, -0.03593468,  0.04195067,
#          -0.01710625, -0.04313778],
#         [-0.03611733,  0.02915761,  0.00326975, -0.04671866,
#          -0.01129211, -0.02177311, -0.03593468,  0.04195067,
#          -0.01710625, -0.04313778],
#         [-0.03611733,  0.02915761,  0.00326975, -0.04671866,
#          -0.01129211, -0.02177311, -0.03593468,  0.04195067,
#          -0.01710625, -0.04313778],
#         [-0.02994334, -0.01358159,  0.04053667,  0.01019569,
#           0.03716693,  0.04119015,  0.049212  ,  0.04843136,
#          -0.01219583,  0.02202605],
#         [-0.0241388 , -0.00855054,  0.04701408, -0.02643153,
#           0.04053856, -0.04300989, -0.02631006, -0.01005584,
#          -0.04359517,  0.00297047],
#         [-0.01246744, -0.02971818, -0.01459314,  0.02737241,
#           0.03136139,  0.02921854,  0.03686709,  0.00905712,
#           0.00560155, -0.02899699],
#         [-0.04633006,  0.00451602,  0.00017029, -0.03736377,
#          -0.01642824, -0.01172442,  0.02782973,  0.02503386,
#           0.04141965,  0.01033479]],
#
#        [[-0.03611733,  0.02915761,  0.00326975, -0.04671866,
#          -0.01129211, -0.02177311, -0.03593468,  0.04195067,
#          -0.01710625, -0.04313778],
#         [-0.03611733,  0.02915761,  0.00326975, -0.04671866,
#          -0.01129211, -0.02177311, -0.03593468,  0.04195067,
#          -0.01710625, -0.04313778],
#         [-0.03611733,  0.02915761,  0.00326975, -0.04671866,
#          -0.01129211, -0.02177311, -0.03593468,  0.04195067,
#          -0.01710625, -0.04313778],
#         [-0.03611733,  0.02915761,  0.00326975, -0.04671866,
#          -0.01129211, -0.02177311, -0.03593468,  0.04195067,
#          -0.01710625, -0.04313778],
#         [-0.02994334, -0.01358159,  0.04053667,  0.01019569,
#           0.03716693,  0.04119015,  0.049212  ,  0.04843136,
#          -0.01219583,  0.02202605],
#         [-0.0241388 , -0.00855054,  0.04701408, -0.02643153,
#           0.04053856, -0.04300989, -0.02631006, -0.01005584,
#          -0.04359517,  0.00297047],
#         [-0.01246744, -0.02971818, -0.01459314,  0.02737241,
#           0.03136139,  0.02921854,  0.03686709,  0.00905712,
#           0.00560155, -0.02899699],
#         [-0.02992873, -0.0110672 ,  0.01042904, -0.03519474,
#          -0.00284777,  0.01695916,  0.03389955,  0.00219744,
#           0.03006363, -0.02918735]],
#
#        [[-0.03611733,  0.02915761,  0.00326975, -0.04671866,
#          -0.01129211, -0.02177311, -0.03593468,  0.04195067,
#          -0.01710625, -0.04313778],
#         [-0.03611733,  0.02915761,  0.00326975, -0.04671866,
#          -0.01129211, -0.02177311, -0.03593468,  0.04195067,
#          -0.01710625, -0.04313778],
#         [-0.03611733,  0.02915761,  0.00326975, -0.04671866,
#          -0.01129211, -0.02177311, -0.03593468,  0.04195067,
#          -0.01710625, -0.04313778],
#         [-0.03611733,  0.02915761,  0.00326975, -0.04671866,
#          -0.01129211, -0.02177311, -0.03593468,  0.04195067,
#          -0.01710625, -0.04313778],
#         [-0.02994334, -0.01358159,  0.04053667,  0.01019569,
#           0.03716693,  0.04119015,  0.049212  ,  0.04843136,
#          -0.01219583,  0.02202605],
#         [ 0.04953993, -0.01655728, -0.04919729,  0.00778691,
#          -0.03095677,  0.03950929,  0.02795812,  0.00808955,
#          -0.01177714, -0.01911421],
#         [-0.01246744, -0.02971818, -0.01459314,  0.02737241,
#           0.03136139,  0.02921854,  0.03686709,  0.00905712,
#           0.00560155, -0.02899699],
#         [-0.00214421, -0.01932491, -0.04848025, -0.00233384,
#          -0.04753995, -0.00579815, -0.03421514, -0.01581241,
#          -0.03914666, -0.01622049]],
#
#        [[-0.03611733,  0.02915761,  0.00326975, -0.04671866,
#          -0.01129211, -0.02177311, -0.03593468,  0.04195067,
#          -0.01710625, -0.04313778],
#         [-0.03611733,  0.02915761,  0.00326975, -0.04671866,
#          -0.01129211, -0.02177311, -0.03593468,  0.04195067,
#          -0.01710625, -0.04313778],
#         [-0.03611733,  0.02915761,  0.00326975, -0.04671866,
#          -0.01129211, -0.02177311, -0.03593468,  0.04195067,
#          -0.01710625, -0.04313778],
#         [ 0.04323942,  0.01442479,  0.02018737,  0.00186776,
#           0.03237441,  0.00230554,  0.04709946, -0.03079762,
#           0.04455954,  0.00583198],
#         [ 0.03232991, -0.03858012, -0.04803104, -0.02617303,
#           0.03127563,  0.04409241,  0.04478618, -0.00868547,
#          -0.00724415, -0.01509622],
#         [-0.01597822,  0.01778615,  0.01483661, -0.01329386,
#           0.01628749,  0.02728734, -0.0038057 ,  0.01102482,
#           0.00534443,  0.01405549],
#         [ 0.012577  , -0.00408108,  0.01104183, -0.02352856,
#           0.01669369,  0.04623404,  0.00478059, -0.02243297,
#          -0.01625108,  0.0308275 ],
#         [ 0.04570619, -0.03316069, -0.03599709,  0.01968688,
#          -0.02643719, -0.00346584, -0.03678992,  0.04749015,
#          -0.02502453, -0.04072143]],
#
#        [[-0.03611733,  0.02915761,  0.00326975, -0.04671866,
#          -0.01129211, -0.02177311, -0.03593468,  0.04195067,
#          -0.01710625, -0.04313778],
#         [-0.03611733,  0.02915761,  0.00326975, -0.04671866,
#          -0.01129211, -0.02177311, -0.03593468,  0.04195067,
#          -0.01710625, -0.04313778],
#         [-0.03611733,  0.02915761,  0.00326975, -0.04671866,
#          -0.01129211, -0.02177311, -0.03593468,  0.04195067,
#          -0.01710625, -0.04313778],
#         [ 0.04323942,  0.01442479,  0.02018737,  0.00186776,
#           0.03237441,  0.00230554,  0.04709946, -0.03079762,
#           0.04455954,  0.00583198],
#         [ 0.03232991, -0.03858012, -0.04803104, -0.02617303,
#           0.03127563,  0.04409241,  0.04478618, -0.00868547,
#          -0.00724415, -0.01509622],
#         [-0.01597822,  0.01778615,  0.01483661, -0.01329386,
#           0.01628749,  0.02728734, -0.0038057 ,  0.01102482,
#           0.00534443,  0.01405549],
#         [ 0.012577  , -0.00408108,  0.01104183, -0.02352856,
#           0.01669369,  0.04623404,  0.00478059, -0.02243297,
#          -0.01625108,  0.0308275 ],
#         [ 0.03232991, -0.03858012, -0.04803104, -0.02617303,
#           0.03127563,  0.04409241,  0.04478618, -0.00868547,
#          -0.00724415, -0.01509622]],
#
#        [[-0.03611733,  0.02915761,  0.00326975, -0.04671866,
#          -0.01129211, -0.02177311, -0.03593468,  0.04195067,
#          -0.01710625, -0.04313778],
#         [-0.03611733,  0.02915761,  0.00326975, -0.04671866,
#          -0.01129211, -0.02177311, -0.03593468,  0.04195067,
#          -0.01710625, -0.04313778],
#         [-0.03611733,  0.02915761,  0.00326975, -0.04671866,
#          -0.01129211, -0.02177311, -0.03593468,  0.04195067,
#          -0.01710625, -0.04313778],
#         [-0.01397245,  0.01340193,  0.03816699, -0.00962389,
#           0.00833163, -0.04601872,  0.0467639 ,  0.0296579 ,
#          -0.03943   ,  0.03343901],
#         [-0.02994334, -0.01358159,  0.04053667,  0.01019569,
#           0.03716693,  0.04119015,  0.049212  ,  0.04843136,
#          -0.01219583,  0.02202605],
#         [-0.01833502, -0.00670192, -0.0479992 ,  0.0493541 ,
#          -0.04409549, -0.0381308 , -0.03551084,  0.02608702,
#          -0.00728308, -0.03304817],
#         [-0.01246744, -0.02971818, -0.01459314,  0.02737241,
#           0.03136139,  0.02921854,  0.03686709,  0.00905712,
#           0.00560155, -0.02899699],
#         [ 0.00585157, -0.01845912,  0.04232388,  0.03804989,
#           0.0043695 , -0.02976555,  0.0259863 ,  0.04475759,
#           0.02883229,  0.01316173]],
#
#        [[-0.03611733,  0.02915761,  0.00326975, -0.04671866,
#          -0.01129211, -0.02177311, -0.03593468,  0.04195067,
#          -0.01710625, -0.04313778],
#         [-0.03611733,  0.02915761,  0.00326975, -0.04671866,
#          -0.01129211, -0.02177311, -0.03593468,  0.04195067,
#          -0.01710625, -0.04313778],
#         [-0.03611733,  0.02915761,  0.00326975, -0.04671866,
#          -0.01129211, -0.02177311, -0.03593468,  0.04195067,
#          -0.01710625, -0.04313778],
#         [-0.03611733,  0.02915761,  0.00326975, -0.04671866,
#          -0.01129211, -0.02177311, -0.03593468,  0.04195067,
#          -0.01710625, -0.04313778],
#         [-0.04313434,  0.02604929,  0.00141446, -0.0236712 ,
#           0.02435474,  0.03233081, -0.03802612,  0.03709726,
#          -0.03780676, -0.04654947],
#         [ 0.02494148,  0.01764447, -0.04593326,  0.03298378,
#          -0.03700507, -0.00901922,  0.04658325, -0.04189459,
#           0.0218136 ,  0.00863702],
#         [-0.04622431, -0.02484491, -0.01916555, -0.04784666,
#           0.04594317, -0.02692815, -0.02710666,  0.04363957,
#           0.00695765, -0.04879512],
#         [ 0.012577  , -0.00408108,  0.01104183, -0.02352856,
#           0.01669369,  0.04623404,  0.00478059, -0.02243297,
#          -0.01625108,  0.0308275 ]]], dtype=float32)
