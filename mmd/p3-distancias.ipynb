# %%
import numpy as np
import pandas as pd

# pacotes para obter as distâncias
from scipy.spatial.distance import squareform, pdist
from sklearn.metrics.pairwise import euclidean_distances

pd.options.display.float_format = '{:.2f}'.format    # pandas: para todos os números aparecerem com duas casas decimais
np.set_printoptions(precision=2, suppress=True)      # numpy: para todos os números aparecerem com duas casas decimais

# %% [markdown]
# **Matriz de dados $\boldsymbol{X}_{n \times p}$**

# %% [markdown]
# Seja $X_{4 \times 3}$ =
# - $7 \quad 3 \quad 9$
# - $4 \quad 6 \quad 11$
# - $4 \quad 2 \quad 5$
# - $5 \quad 5 \quad 7$

# %%
# montar a matriz
X = np.array([[7, 3, 9], [4, 6, 11], [4, 2, 5], [5, 5, 7]])
print(X)
# Out:
# [[ 7  3  9]
#  [ 4  6 11]
#  [ 4  2  5]
#  [ 5  5  7]]

# %% [markdown]
# Obter o vetor de médias: $\boldsymbol{\bar{X}}_{p \times 1}$

# %%
Xb = np.mean(X, axis=0).reshape(3, 1)
print(Xb)
# Out:
# [[5.]
#  [4.]
#  [8.]]

# %% [markdown]
# Matriz de covariâncias amostrais: $\boldsymbol{S}_{p \times p}$

# %%
S = np.cov(X.T)
print(S)
# Out:
# [[ 2.   -0.67  0.67]
#  [-0.67  3.33  3.33]
#  [ 0.67  3.33  6.67]]

# %% [markdown]
# # Distâncias entre as observações

# %% [markdown]
# ## Distância euclidiana
#
# $d_{ij} = \sqrt{\sum_{k=1}^{p} (X_{ik} - X_{jk})^2}$

# %%
# usando scipy
squareform(pdist(X, metric='euclidean'))
# Out:
# array([[0.  , 4.69, 5.1 , 3.46],
#        [4.69, 0.  , 7.21, 4.24],
#        [5.1 , 7.21, 0.  , 3.74],
#        [3.46, 4.24, 3.74, 0.  ]])

# %%
# usando scikit-learn
D = euclidean_distances(X, X)
D
# Out:
# array([[0.  , 4.69, 5.1 , 3.46],
#        [4.69, 0.  , 7.21, 4.24],
#        [5.1 , 7.21, 0.  , 3.74],
#        [3.46, 4.24, 3.74, 0.  ]])

# %% [markdown]
# ## Dessa forma não precisa, é apenas curiosidade

# %% [markdown]
# Matricialmente:
#
# $d^2_{ij} = (\boldsymbol{X_{i \cdot}} - \boldsymbol{X_{j \cdot}})^T (\boldsymbol{X_{i \cdot}} - \boldsymbol{X_{j \cdot}})$

# %% [markdown]
# Obter os vetores $\boldsymbol{X}_{1\cdot}$, $\boldsymbol{X}_{2\cdot}$, $\cdots$

# %%
X
# Out:
# array([[ 7,  3,  9],
#        [ 4,  6, 11],
#        [ 4,  2,  5],
#        [ 5,  5,  7]])

# %%
X1p = X[0,:].reshape(3, 1)
X2p = X[1,:].reshape(3, 1)
X3p = X[2,:].reshape(3, 1)
X4p = X[3,:].reshape(3, 1)

# %%
# distância entre as observações 1 e 2
d12 = ((X1p - X2p).T @ (X1p - X2p)) ** 0.5
d12
# Out:
# array([[4.69]])

# %%
# da mesma forma obteríamos as outras: d13, d14, d23, d24

# %% [markdown]
# ## Distância euclidiana padronizada
#
# $d_{ij} = \sqrt{\sum_{k=1}^{p}\dfrac{(X_{ik} - X_{jk})^2}{S_{kk}}}$

# %%
# usando scipy
squareform(pdist(X, metric='seuclidean'))
# Out:
# array([[0.  , 2.79, 2.68, 1.95],
#        [2.79, 0.  , 3.19, 1.79],
#        [2.68, 3.19, 0.  , 1.95],
#        [1.95, 1.79, 1.95, 0.  ]])

# %% [markdown]
# Matricialmente (não precisa):
#
# $d^2_{ij} = (\boldsymbol{X_{i \cdot}} - \boldsymbol{X_{j \cdot}})^T \boldsymbol{D}^{-1} (\boldsymbol{X_{i \cdot}} - \boldsymbol{X_{j \cdot}})$,
#
# em que $\boldsymbol{D}^{-1} = diag(1/S_{ii})$

# %%
S
# Out:
# array([[ 2.  , -0.67,  0.67],
#        [-0.67,  3.33,  3.33],
#        [ 0.67,  3.33,  6.67]])

# %%
# D**{-1}
D1 = np.diag(1 / np.diag(S))
print(D1)
# Out:
# [[0.5  0.   0.  ]
#  [0.   0.3  0.  ]
#  [0.   0.   0.15]]

# %%
# distância entre as observações 1 e 2
d12 = ((X1p - X2p).T @ D1 @ (X1p - X2p)) ** 0.5
d12
# Out:
# array([[2.79]])

# %%
# as outras distâncias

# %% [markdown]
# ## Distância de Mahalanobis
#
# $d^2_{ij} = (\boldsymbol{X_{i \cdot}} - \boldsymbol{X_{j \cdot}})^T \boldsymbol{S}^{-1} (\boldsymbol{X_{i \cdot}} - \boldsymbol{X_{j \cdot}})$,
#
# em que $\boldsymbol{S}^{-1}$ é a inversa de $\boldsymbol{S}$

# %%
# usando scipy
squareform(pdist(X, metric='mahalanobis'))
# Out:
# array([[0.  , 2.45, 2.45, 2.45],
#        [2.45, 0.  , 2.45, 2.45],
#        [2.45, 2.45, 0.  , 2.45],
#        [2.45, 2.45, 2.45, 0.  ]])

# %%
# S**{-1}
S1 = np.linalg.inv(S)
print(S1)
# Out:
# [[ 0.75  0.45 -0.3 ]
#  [ 0.45  0.87 -0.48]
#  [-0.3  -0.48  0.42]]

# %%
# distância entre as observações 1 e 2
# curiosidade
d12 = ((X1p - X2p).T @ S1 @ (X1p - X2p)) ** 0.5
d12
# Out:
# array([[2.45]])

# %%
# e as outras distâncias da mesma forma

# %% [markdown]
# # Ler um csv (dataframe)

# %%
medidas = pd.read_csv('https://patriciasiqueira.github.io/arquivos/medidas.csv')

# %%
medidas.shape
# Out:
# (20, 4)

# %%
# apenas variáveis numéricas
medidas = medidas.loc[:, ['torax', 'cintura', 'quadril']]

# %%
# primeiras observações
medidas.head()
# Out:
#    torax  cintura  quadril
# 0     34       30       32
# 1     37       32       37
# 2     38       30       36
# 3     36       33       39
# 4     38       29       33

# %%
# médias das variáveis usando o pacote pandas
medidas.mean()
# Out:
# torax     37.00
# cintura   28.00
# quadril   37.05
# dtype: float64

# %%
# covariâncias das variáveis usando o pacote pandas
medidas.cov()
# Out:
#          torax  cintura  quadril
# torax     6.63     6.37     3.00
# cintura   6.37    12.53     3.58
# quadril   3.00     3.58     5.94

# %%
# correlações entre as variáveis usando o pacote pandas
medidas.corr()
# Out:
#          torax  cintura  quadril
# torax     1.00     0.70     0.48
# cintura   0.70     1.00     0.41
# quadril   0.48     0.41     1.00

# %% [markdown]
# ## Transformando em matriz

# %%
# subselecionar variáveis e transformar em matriz
X = medidas.values[:, 0:3]
# mudar o tipo dos dados
X = np.asarray(X, dtype=float)

# %%
# ou
X = medidas.to_numpy()
X
# Out:
# array([[34, 30, 32],
#        [37, 32, 37],
#        [38, 30, 36],
#        [36, 33, 39],
#        [38, 29, 33],
#        [43, 32, 38],
#        [40, 33, 42],
#        [38, 30, 40],
#        [40, 30, 37],
#        [41, 32, 39],
#        [36, 24, 35],
#        [36, 25, 37],
#        [34, 24, 37],
#        [33, 22, 34],
#        [36, 26, 38],
#        [37, 26, 37],
#        [34, 25, 38],
#        [36, 26, 37],
#        [38, 28, 40],
#        [35, 23, 35]])

# %%
# número de observações
n = X.shape[0]
n
# Out:
# 20

# %%
# número de variáveis
p = X.shape[1]
p
# Out:
# 3

# %% [markdown]
# Obter as matrizes de distâncias (dos três tipos vistos) entre as observações:

# %%
# apenas mostrar a matriz de distâncias euclidiana
squareform(pdist(X, metric='euclidean'))
# Out:
# array([[  0.  ,  42.74,  63.81,  34.85,  46.82,  66.56,  34.5 ,  24.08,
#          77.25,  69.  ,  69.72,  42.57,  72.79,  25.28,  36.36,  37.91],
#        [ 42.74,   0.  ,  46.49,  30.15,  31.26,  38.99,  20.52,  34.74,
#          70.66,  31.78,  35.46,  59.03,  43.58,  29.08,   9.23,  27.97],
#        [ 63.81,  46.49,   0.  ,  38.52,  49.59,  33.48,  38.92,  70.13,
#          37.96,  37.8 ,  36.91,  93.76,  38.82,  47.92,  42.86,  61.24],
#        [ 34.85,  30.15,  38.52,   0.  ,  46.2 ,  50.32,  23.19,  40.98,
#          48.8 ,  48.89,  51.78,  62.81,  57.68,  26.87,  24.76,  40.73],
#        [ 46.82,  31.26,  49.59,  46.2 ,   0.  ,  38.97,  24.56,  40.  ,
#          79.19,  35.88,  33.25,  59.82,  32.96,  37.43,  30.17,  40.6 ],
#        [ 66.56,  38.99,  33.48,  50.32,  38.97,   0.  ,  42.1 ,  64.65,
#          70.06,  26.92,  22.95,  91.1 ,  22.9 ,  53.52,  40.18,  60.59],
#        [ 34.5 ,  20.52,  38.92,  23.19,  24.56,  42.1 ,   0.  ,  34.06,
#          60.86,  36.45,  37.89,  55.74,  42.44,  20.03,  14.33,  29.6 ],
#        [ 24.08,  34.74,  70.13,  40.98,  40.  ,  64.65,  34.06,   0.  ,
#          88.02,  62.69,  64.17,  29.08,  68.42,  34.12,  33.22,  34.93],
#        [ 77.25,  70.66,  37.96,  48.8 ,  79.19,  70.06,  60.86,  88.02,
#           0.  ,  68.74,  70.25, 106.42,  74.21,  64.97,  66.03,  79.32],
#        [ 69.  ,  31.78,  37.8 ,  48.89,  35.88,  26.92,  36.45,  62.69,
#          68.74,   0.  ,   8.53,  84.44,  19.71,  50.95,  35.05,  51.2 ],
#        [ 69.72,  35.46,  36.91,  51.78,  33.25,  22.95,  37.89,  64.17,
#          70.25,   8.53,   0.  ,  86.46,  12.62,  52.47,  37.95,  54.18],
#        [ 42.57,  59.03,  93.76,  62.81,  59.82,  91.1 ,  55.74,  29.08,
#         106.42,  84.44,  86.46,   0.  ,  90.3 ,  54.59,  57.65,  50.53],
# [5 rows x 42 columns]

# %%
mg.shape
# Out:
# (853, 42)

# %%
# selecionar microrregião de Varginha
vgn = mg.query('nome_micro == "Varginha"')
vgn
# Out:
#        ibge7  meso              nome_meso  micro nome_micro  \
# 75   3107109  3110  Sul/Sudoeste de Minas  31050   Varginha
# 117  3110905  3110  Sul/Sudoeste de Minas  31050   Varginha
# 122  3111309  3110  Sul/Sudoeste de Minas  31050   Varginha
# 125  3111606  3110  Sul/Sudoeste de Minas  31050   Varginha
# 150  3113909  3110  Sul/Sudoeste de Minas  31050   Varginha
# 205  3118700  3110  Sul/Sudoeste de Minas  31050   Varginha
# 263  3123601  3110  Sul/Sudoeste de Minas  31050   Varginha
# 318  3128105  3110  Sul/Sudoeste de Minas  31050   Varginha
# 345  3130507  3110  Sul/Sudoeste de Minas  31050   Varginha
# 491  3142601  3110  Sul/Sudoeste de Minas  31050   Varginha
# 679  3158300  3110  Sul/Sudoeste de Minas  31050   Varginha
# 707  3160801  3110  Sul/Sudoeste de Minas  31050   Varginha
# 764  3165206  3110  Sul/Sudoeste de Minas  31050   Varginha
# 812  3169307  3110  Sul/Sudoeste de Minas  31050   Varginha
# 814  3169406  3110  Sul/Sudoeste de Minas  31050   Varginha
# 833  3170701  3110  Sul/Sudoeste de Minas  31050   Varginha
#
#                      mun  tx_mort_acid_15_29  tx_mort_hom_15_29  tx_mort_mama  \
# 75         Boa Esperança               60.75              19.07         25.98
# 117             Campanha               25.91               0.00         13.03
# 122        Campo do Meio                0.00              32.32         17.71
# 125        Campos Gerais               29.90              26.98         22.16
# 150   Carmo da Cachoeira               32.41               0.00          0.00
# 205            Coqueiral                0.00               0.00         21.47
# 263          Elói Mendes               31.99              15.38          7.85
# 318                Guapé               59.26               0.00         15.17
# 345             Ilicínea                0.00              65.00         17.77
# 491      Monsenhor Paulo                0.00               0.00          0.00
# 679    Santana da Vargem                0.00               0.00          0.00
# 707      São Bento Abade               81.90               0.00          0.00
# 764  São Tomé das Letras                0.00               0.00          0.00
# 812        Três Corações               41.71              19.83         16.37
# 814          Três Pontas               29.26               7.03         14.73
# 833             Varginha               43.40               6.10          6.30
#
#      tx_mort_inf  ...   rdpc  renocup  perc_rdpc_140  fam_pbf  tx_emp_form  \
# 75         14.93  ... 599.17   903.37           8.43     2835        24.80
# 117         6.21  ... 686.16  1021.62           6.55      786        27.30
# 122        26.09  ... 472.71   709.35           8.82     1111        18.50
# 125         3.04  ... 503.91   744.47           9.73     2422        18.30
# 150        33.11  ... 525.35   822.31           9.56      987        27.70
# 205        32.97  ... 495.77   714.57          13.64      862        15.10
# 263        16.08  ... 577.50   921.97          10.46     1194        25.00
# 318         7.94  ... 487.68   742.73           7.41     1194        18.40
# 345         7.14  ... 500.79   784.59           6.93      869        28.50
# 491        18.52  ... 555.78   854.92           5.17      492        32.80
# 679        26.32  ... 553.70   813.53           6.47      654        28.10
# 707         0.00  ... 458.65   760.59           9.59      300        12.40
# 764        37.74  ... 428.33   648.83          13.48      415        44.00
# 812        14.40  ... 749.86  1245.57           8.84     3963        33.80
# 814         9.60  ... 682.15  1055.69           6.90     2868        30.00
# 833         5.44  ... 904.57  1382.27           3.83     1746        42.80
#
#      rend_pc_form   pib_pc  perc_agro  perc_serv  tx_ativ_18m
# 75         140.03 13127.48      28.65      39.28        64.92
# 117        149.06 10611.67      33.56      29.17        70.14
# 122        105.89  7836.89      48.22      28.09        67.53
# 125         93.65 11985.82      57.93      25.34        70.96
# 150        133.98 11871.57      47.49      26.25        71.98
# 205         71.00 11402.89      53.59      24.72        66.81
# 263        155.01 13057.12      31.12      34.04        66.07
# 318        102.09  8945.31      43.65      27.00        66.59
# 345        156.11  9364.19      45.01      22.27        68.14
# 491        194.62 14457.20      40.17      22.52        71.95
# 679        142.50 15154.94      49.45      27.35        74.17
# 707         81.72  9054.98      57.44      18.19        77.10
# 764        239.46  8559.06      23.58      25.52        77.57
# 812        257.27 24161.24      12.02      42.41        69.23
# 814        180.56 13712.40      31.21      34.37        71.75
# 833        344.56 32144.45       5.94      46.41        70.37
#
# [16 rows x 42 columns]

# %%
vgn.shape
# Out:
# (16, 42)

# %%
# zerar os índices
vgn = vgn.reset_index().drop('index', axis=1)

# %%
vgn
# Out:
#       ibge7  meso              nome_meso  micro nome_micro  \
# 0   3107109  3110  Sul/Sudoeste de Minas  31050   Varginha
# 1   3110905  3110  Sul/Sudoeste de Minas  31050   Varginha
# 2   3111309  3110  Sul/Sudoeste de Minas  31050   Varginha
# 3   3111606  3110  Sul/Sudoeste de Minas  31050   Varginha
# 4   3113909  3110  Sul/Sudoeste de Minas  31050   Varginha
# 5   3118700  3110  Sul/Sudoeste de Minas  31050   Varginha
# 6   3123601  3110  Sul/Sudoeste de Minas  31050   Varginha
# 7   3128105  3110  Sul/Sudoeste de Minas  31050   Varginha
# 8   3130507  3110  Sul/Sudoeste de Minas  31050   Varginha
# 9   3142601  3110  Sul/Sudoeste de Minas  31050   Varginha
# 10  3158300  3110  Sul/Sudoeste de Minas  31050   Varginha
# 11  3160801  3110  Sul/Sudoeste de Minas  31050   Varginha
# 12  3165206  3110  Sul/Sudoeste de Minas  31050   Varginha
# 13  3169307  3110  Sul/Sudoeste de Minas  31050   Varginha
# 14  3169406  3110  Sul/Sudoeste de Minas  31050   Varginha
# 15  3170701  3110  Sul/Sudoeste de Minas  31050   Varginha
#
#                     mun  tx_mort_acid_15_29  tx_mort_hom_15_29  tx_mort_mama  \
# 0         Boa Esperança               60.75              19.07         25.98
# 1              Campanha               25.91               0.00         13.03
# 2         Campo do Meio                0.00              32.32         17.71
# 3         Campos Gerais               29.90              26.98         22.16
# 4    Carmo da Cachoeira               32.41               0.00          0.00
# 5             Coqueiral                0.00               0.00         21.47
# 6           Elói Mendes               31.99              15.38          7.85
# 7                 Guapé               59.26               0.00         15.17
# 8              Ilicínea                0.00              65.00         17.77
# 9       Monsenhor Paulo                0.00               0.00          0.00
# 10    Santana da Vargem                0.00               0.00          0.00
# 11      São Bento Abade               81.90               0.00          0.00
# 12  São Tomé das Letras                0.00               0.00          0.00
# 13        Três Corações               41.71              19.83         16.37
# 14          Três Pontas               29.26               7.03         14.73
# 15             Varginha               43.40               6.10          6.30
#
#     tx_mort_inf  ...   rdpc  renocup  perc_rdpc_140  fam_pbf  tx_emp_form  \
# mun
# Boa Esperança                  42.57                72.79          25.28
# Campanha                       59.03                43.58          29.08
# Campo do Meio                  93.76                38.82          47.92
# Campos Gerais                  62.81                57.68          26.87
# Carmo da Cachoeira             59.82                32.96          37.43
# Coqueiral                      91.10                22.90          53.52
# Elói Mendes                    55.74                42.44          20.03
# Guapé                          29.08                68.42          34.12
# Ilicínea                      106.42                74.21          64.97
# Monsenhor Paulo                84.44                19.71          50.95
# Santana da Vargem              86.46                12.62          52.47
# São Bento Abade                 0.00                90.30          54.59
# São Tomé das Letras            90.30                 0.00          57.08
# Três Corações                  54.59                57.08           0.00
# Três Pontas                    57.65                44.76          20.38
# Varginha                       50.53                60.85          21.22
#
# mun                  Três Pontas  Varginha
# mun
# Boa Esperança              36.36     37.91
# Campanha                    9.23     27.97
# Campo do Meio              42.86     61.24
# Campos Gerais              24.76     40.73
# Carmo da Cachoeira         30.17     40.60
# Coqueiral                  40.18     60.59
# Elói Mendes                14.33     29.60
# Guapé                      33.22     34.93
# Ilicínea                   66.03     79.32
# Monsenhor Paulo            35.05     51.20
# Santana da Vargem          37.95     54.18
# São Bento Abade            57.65     50.53
# São Tomé das Letras        44.76     60.85
# Três Corações              20.38     21.22
# Três Pontas                 0.00     24.19
# Varginha                   24.19      0.00

# %%
# escolher municípios para saber as distâncias
Dedf.loc['Varginha', 'Elói Mendes']
# Out:
# np.float64(29.598118183425107)

# %%
Dedf.loc['Varginha', 'Três Corações']
# Out:
# np.float64(21.22158099671182)

# %%
def compara_dist(df, op='max'):
    if op == 'max':
        maximo = np.amax(df.values)
        a = np.where(df.values == maximo)
    else:
        df = df[df > 0]
        minimo = np.nanmin(df.values)
        a = np.where(df.values == minimo)
    return [df.index[a[0][0]], df.index[a[0][1]]]

# %%
# municípios mais semelhantes de acordo com a distância euclidiana
compara_dist(Dedf,'min')
# Out:
# ['Monsenhor Paulo', 'Santana da Vargem']

# %%
# municípios mais diferentes de acordo com a distância euclidiana
compara_dist(Dedf)
# Out:
# ['Ilicínea', 'São Bento Abade']

# %% [markdown]
# Distância euclidiana padronizada

# %%
Dep = squareform(pdist(X, metric='seuclidean'))

# %%
# incluir nomes dos municípios nas distâncias - euclidiana padronizada
Dedf_ep = pd.DataFrame(Dep, index=vgn.mun, columns=vgn.mun)

# %%
# municípios mais semelhantes de acordo com a distância euclidiana padronizada
compara_dist(Dedf_ep,'min')
# Out:
# ['Campanha', 'Três Pontas']

# %%
# municípios mais diferentes de acordo com a distância euclidiana padronizada
compara_dist(Dedf_ep)
# Out:
# ['São Tomé das Letras', 'Varginha']

# %% [markdown]
# Distância de Mahalanobis

# %%
Dm = squareform(pdist(X, metric='mahalanobis'))

# %%
# incluir nomes dos municípios nas distâncias - Mahalanobis
Dedf_m = pd.DataFrame(Dm, index=vgn.mun, columns=vgn.mun)

# %%
# municípios mais semelhantes de acordo com a distância de Mahalanobis
compara_dist(Dedf_m,'min')
# Out:
# ['Campanha', 'Três Pontas']

# %%
# municípios mais diferentes de acordo com a distância de Mahalanobis
compara_dist(Dedf_m)
# Out:
# ['Coqueiral', 'São Bento Abade']
